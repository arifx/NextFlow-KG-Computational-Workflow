# %%
# !git clone https://github.com/arifx/NextFlow-KG-Computational-Workflow.git
# Out:
# Cloning into 'NextFlow-KG-Computational-Workflow'...
# remote: Enumerating objects: 342, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 342 (delta 102), reused 158 (delta 101), pack-reused 182
# Receiving objects: 100% (342/342), 14.53 MiB | 50.61 MiB/s, done.
# Resolving deltas: 100% (206/206), done.

# %%
cd ./NextFlow-KG-Computational-Workflow
# Out:
# /content/NextFlow-KG-Computational-Workflow

# %%
# !git pull

# %%
# !bash processDitectDatasets.sh
# Out:
#       N E X T F L O W
#       version 23.04.1 build 5866
#       created 15-04-2023 06:51 UTC
#       cite doi:10.1038/nbt.3820
#       http://nextflow.io
#
#
# Nextflow installation completed. Please note:
# - the executable file `nextflow` has been created in the folder: /content/NextFlow-KG-Computational-Workflow
# - you may complete the installation by moving it to a directory in your $PATH
#
#
#       N E X T F L O W
#       version 23.04.1 build 5866
#       created 15-04-2023 06:51 UTC
#       cite doi:10.1038/nbt.3820
#       http://nextflow.io
#
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# mkdir: cannot create directory ‘result/’: File exists
# mkdir: cannot create directory ‘result/KG’: File exists
# mkdir: cannot create directory ‘result/KG/FTIR’: File exists
# mkdir: cannot create directory ‘result/KG/MSI’: File exists
# mkdir: cannot create directory ‘result/KG/MSIF’: File exists
# ...
